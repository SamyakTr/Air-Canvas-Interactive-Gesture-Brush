# %% [markdown]
# <a href="https://colab.research.google.com/github/SamyakTr/Air-Canvas-Interactive-Gesture-Brush/blob/main/Data_Wrangling(Seattle_Data).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing necessary libraries

# %%
import os
import gdown
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Importing csv file(dataset)

# %%
# !gdown https://drive.google.com/uc?id=1eHCSLdQBtnKIoAALJaZWzULpV-6SERyZ
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1eHCSLdQBtnKIoAALJaZWzULpV-6SERyZ
# From (redirected): https://drive.google.com/uc?id=1eHCSLdQBtnKIoAALJaZWzULpV-6SERyZ&confirm=t&uuid=3c7d103e-79ac-4cd8-bd6e-5a969a9ce505
# To: /content/SDOT_Collisions.csv
# 100% 161M/161M [00:05<00:00, 30.5MB/s]

# %%
df=pd.read_csv("/content/SDOT_Collisions.csv")
# Out:
# <ipython-input-7-14363d273147>:1: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("/content/SDOT_Collisions.csv")

# %%
df.head()
# Out:
#    OBJECTID SE_ANNO_CAD_DATA  INCKEY  COLDETKEY REPORTNO   STATUS  \
# 0   5955724    System.Byte[]  359371     360851  3900360  Matched
# 1   5955725    System.Byte[]  362680     364160  3904129  Matched
# 2   5955726    System.Byte[]  365797     367277  ED63058  Matched
# 3   5955727    System.Byte[]  366458     367938  EE05029  Matched
# 4   5955728    System.Byte[]  366244     367724  EE06457  Matched
#
#        ADDRTYPE   INTKEY                                          LOCATION  \
# 0  Intersection  29504.0                        DENNY WAY AND FAIRVIEW AVE
# 1         Block      NaN  RAINIER AVE S BETWEEN S HOLLY ST AND S WILLOW ST
# 2         Block      NaN              2ND AVE BETWEEN UNION ST AND PIKE ST
# 3  Intersection  28884.0                              2ND AVE N AND ROY ST
# 4  Intersection  27065.0                        11TH AVE NE AND NE 45TH ST
#
#   EXCEPTRSNCODE  ... HITPARKEDCAR    SPDCASENO Source of the collision report  \
# ...

# %% [markdown]
# gives the first five datas from the dataset

# %%
df.tail()
# Out:
#         OBJECTID SE_ANNO_CAD_DATA  INCKEY  COLDETKEY REPORTNO     STATUS  \
# 248289   6204013    System.Byte[]  369096     370576  EE37823  Unmatched
# 248290   6204014    System.Byte[]  366728     368208  EE09629  Unmatched
# 248291   6204015    System.Byte[]  369171     370651  3922716  Unmatched
# 248292   6204016    System.Byte[]  367345     368825  3914629  Unmatched
# 248293   6204017    System.Byte[]  368476     369956  3906699  Unmatched
#
#             ADDRTYPE   INTKEY  \
# 248289  Intersection  29622.0
# 248290         Block      NaN
# 248291  Intersection  29863.0
# 248292         Block      NaN
# 248293         Block      NaN
#
#                                                  LOCATION EXCEPTRSNCODE  ...  \
# 248289                              1ST AVE AND MARION ST           NaN  ...
# 248290  WALLINGFORD AVE N BETWEEN N 80TH ST AND N 82ND ST           NEI  ...
# 248291                            MELROSE AVE AND PINE ST           NaN  ...
# ...

# %% [markdown]
# gives the first five datas from the dataset

# %%
df.columns
# Out:
# Index(['OBJECTID', 'SE_ANNO_CAD_DATA', 'INCKEY', 'COLDETKEY', 'REPORTNO',
#        'STATUS', 'ADDRTYPE', 'INTKEY', 'LOCATION', 'EXCEPTRSNCODE',
#        'EXCEPTRSNDESC', 'SEVERITYCODE', 'SEVERITYDESC', 'COLLISIONTYPE',
#        'PERSONCOUNT', 'PEDCOUNT', 'PEDCYLCOUNT', 'VEHCOUNT', 'INJURIES',
#        'SERIOUSINJURIES', 'FATALITIES', 'INCDATE', 'INCDTTM', 'JUNCTIONTYPE',
#        'SDOT_COLCODE', 'SDOT_COLDESC', 'INATTENTIONIND', 'UNDERINFL',
#        'WEATHER', 'ROADCOND', 'LIGHTCOND', 'DIAGRAMLINK', 'REPORTLINK',
#        'PEDROWNOTGRNT', 'SDOTCOLNUM', 'SPEEDING', 'STCOLCODE', 'ST_COLDESC',
#        'SEGLANEKEY', 'CROSSWALKKEY', 'HITPARKEDCAR', 'SPDCASENO',
#        'Source of the collision report', 'Source description', 'Added by User',
#        'Added date', 'Modified by', 'Modified date', 'x', 'y'],
#       dtype='object')

# %% [markdown]
# Shows the names of columns in database

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 248294 entries, 0 to 248293
# Data columns (total 50 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   OBJECTID                        248294 non-null  int64
#  1   SE_ANNO_CAD_DATA                248294 non-null  object
#  2   INCKEY                          248294 non-null  int64
#  3   COLDETKEY                       248294 non-null  int64
#  4   REPORTNO                        248294 non-null  object
#  5   STATUS                          248294 non-null  object
#  6   ADDRTYPE                        244359 non-null  object
#  7   INTKEY                          82824 non-null   float64
#  8   LOCATION                        243421 non-null  object
#  9   EXCEPTRSNCODE                   12790 non-null   object
#  10  EXCEPTRSNDESC                   12790 non-null   object
#  11  SEVERITYCODE                    248293 non-null  object
# ...

# %% [markdown]
# shows the ypes of data that is contained in the dataset

# %%
df.describe()
# Out:
#            OBJECTID         INCKEY      COLDETKEY         INTKEY  \
# count  2.482940e+05  248294.000000  248294.000000   82824.000000
# mean   6.079870e+06  167160.624365  167524.882836   38205.640913
# std    7.167645e+04  106037.254473  106554.937782   54469.905194
# min    5.955724e+06    1001.000000    1001.000000   23807.000000
# 25%    6.017797e+06   78362.250000   78362.250000   28667.000000
# 50%    6.079870e+06  140828.500000  140828.500000   30102.000000
# 75%    6.141944e+06  244848.750000  245448.750000   34082.000000
# max    6.204017e+06  371192.000000  372672.000000  858453.000000
#
#          PERSONCOUNT       PEDCOUNT    PEDCYLCOUNT       VEHCOUNT  \
# count  248294.000000  248294.000000  248294.000000  248294.000000
# mean        2.237150       0.038885       0.027814       1.695716
# std         1.442178       0.203710       0.165902       0.862019
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
df[['LOCATION','INJURIES','WEATHER']]
# Out:
#                                                  LOCATION  INJURIES   WEATHER
# 0                              DENNY WAY AND FAIRVIEW AVE         1     Clear
# 1        RAINIER AVE S BETWEEN S HOLLY ST AND S WILLOW ST         0  Overcast
# 2                    2ND AVE BETWEEN UNION ST AND PIKE ST         1     Clear
# 3                                    2ND AVE N AND ROY ST         1  Overcast
# 4                              11TH AVE NE AND NE 45TH ST         1  Overcast
# ...                                                   ...       ...       ...
# 248289                              1ST AVE AND MARION ST         1       NaN
# 248290  WALLINGFORD AVE N BETWEEN N 80TH ST AND N 82ND ST         0       NaN
# 248291                            MELROSE AVE AND PINE ST         1       NaN
# 248292  WESTLAKE AVE N BETWEEN HIGHLAND DR AND GALER S ST         2       NaN
# 248293  1ST AVE S BETWEEN 2ND AV SW ON RP AND SW KENYO...         0       NaN
#
# [248294 rows x 3 columns]

# %% [markdown]
# IN ABOVE CODE, the data of specific columns location, injuries and weather is displayed.

# %%
df.iloc[3:10,4:8]
# Out:
#   REPORTNO   STATUS      ADDRTYPE   INTKEY
# 3  EE05029  Matched  Intersection  28884.0
# 4  EE06457  Matched  Intersection  27065.0
# 5  3904210  Matched  Intersection  34538.0
# 6  ED04008  Matched  Intersection  29051.0
# 7  3904376  Matched         Block      NaN
# 8  3893002  Matched  Intersection  34543.0
# 9  ED30013  Matched         Block      NaN

# %% [markdown]
# iloc is a method based on index to select particular rows and columns.
# In above code, the rows with index 3 to 9 and columns with index 4 to 7 is displayed

# %%
df.loc[2:30,['LOCATION','INJURIES']]
# Out:
#                                              LOCATION  INJURIES
# 2                2ND AVE BETWEEN UNION ST AND PIKE ST         1
# 3                                2ND AVE N AND ROY ST         1
# 4                          11TH AVE NE AND NE 45TH ST         1
# 5                M L KING JR WR WAY S AND S WILLOW ST         2
# 6                       HARVARD AVE E AND E OLIVE WAY         1
# 7    SW THISTLE ST BETWEEN 9TH AVE SW AND 10TH AVE SW         0
# 8                           32ND AVE S AND S HOLLY PL         2
# 9   1ST AVE S BETWEEN S MASSACHUSETTS ST AND S HOL...         0
# 10                                4TH AVE AND PIKE ST         0
# 11                  49TH AVE SW AND SW CHARLESTOWN ST         1
# 12  CALIFORNIA AVE SW BETWEEN SW SOUTHERN ST AND S...         0
# 13  NE 80TH ST BETWEEN 8TH AVE NE AND ROOSEVELT WA...         1
# 14                       WESTLAKE AVE N AND VALLEY ST         1
# 15  N 145TH ST BETWEEN MERIDIAN AVE N AND BAGLEY A...         0
# ...

# %% [markdown]
# loc is used to select particlar dataset based on column names.
# In above code,using loc, the data from index no 2 to 30 for coluumns location and injuries is displayed using loc.

# %%
df.loc[(df['INJURIES']>10),['LOCATION','INJURIES','WEATHER','ROADCOND','LIGHTCOND']]
# Out:
#                                                  LOCATION  INJURIES   WEATHER  \
# 24381        4TH AVE S BETWEEN S STACY ST AND S LANDER ST        11     Clear
# 61157   ELLIOTT AV ON RP BETWEEN ALASKAN WY VI SB AND ...        13   Raining
# 69789   LAKE WASHINGTON BLVD E BETWEEN BOYER AVE E AND...        11     Clear
# 95186   ALASKAN WY VI SB BETWEEN COLUMBIA ST ON RP AND...        11     Clear
# 129564                              BOREN AVE AND PIKE ST        12     Clear
# 152514  WEST SEATTLE BR EB BETWEEN DELRIDGE-W SEATTLE ...        13   Raining
# 153593  RAINIER AVE S BETWEEN STURTEVANT AVE S AND 52N...        15  Overcast
# 162192                         15TH AVE NE AND NE 97TH ST        11     Clear
# 163931         AURORA BR BETWEEN RAYE ST AND BRIDGE WAY N        78     Clear
# 186063  LAKE WASHINGTON BLVD S BETWEEN 53RD AVE S AND ...        11     Clear
# 240362               3RD AVE BETWEEN UNION ST AND PIKE ST        13     Clear
# ...

# %% [markdown]
# above code shows the deatils of where injuries were greater than 10

# %%
df.loc[(df['INJURIES']>10)&(df['SERIOUSINJURIES']>3),['LOCATION','INJURIES','WEATHER','ROADCOND','LIGHTCOND']]
# Out:
#                                                  LOCATION  INJURIES   WEATHER  \
# 153593  RAINIER AVE S BETWEEN STURTEVANT AVE S AND 52N...        15  Overcast
# 163931         AURORA BR BETWEEN RAYE ST AND BRIDGE WAY N        78     Clear
#
#        ROADCOND LIGHTCOND
# 153593      Dry  Daylight
# 163931      Dry  Daylight

# %% [markdown]
# using and operator to display info for conditions where injuries >10 and serrious injuries>3

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [OBJECTID, SE_ANNO_CAD_DATA, INCKEY, COLDETKEY, REPORTNO, STATUS, ADDRTYPE, INTKEY, LOCATION, EXCEPTRSNCODE, EXCEPTRSNDESC, SEVERITYCODE, SEVERITYDESC, COLLISIONTYPE, PERSONCOUNT, PEDCOUNT, PEDCYLCOUNT, VEHCOUNT, INJURIES, SERIOUSINJURIES, FATALITIES, INCDATE, INCDTTM, JUNCTIONTYPE, SDOT_COLCODE, SDOT_COLDESC, INATTENTIONIND, UNDERINFL, WEATHER, ROADCOND, LIGHTCOND, DIAGRAMLINK, REPORTLINK, PEDROWNOTGRNT, SDOTCOLNUM, SPEEDING, STCOLCODE, ST_COLDESC, SEGLANEKEY, CROSSWALKKEY, HITPARKEDCAR, SPDCASENO, Source of the collision report, Source description, Added by User, Added date, Modified by, Modified date, x, y]
# Index: []
#
# [0 rows x 50 columns]

# %%
df.isnull().sum()
# Out:
# OBJECTID                               0
# SE_ANNO_CAD_DATA                       0
# INCKEY                                 0
# COLDETKEY                              0
# REPORTNO                               0
# STATUS                                 0
# ADDRTYPE                            3935
# INTKEY                            165470
# LOCATION                            4873
# EXCEPTRSNCODE                     235504
# EXCEPTRSNDESC                     235504
# SEVERITYCODE                           1
# SEVERITYDESC                           0
# COLLISIONTYPE                      33654
# PERSONCOUNT                            0
# PEDCOUNT                               0
# PEDCYLCOUNT                            0
# VEHCOUNT                               0
# INJURIES                               0
# SERIOUSINJURIES                        0
# FATALITIES                             0
# INCDATE                                0
# INCDTTM                                0
# ...

# %%
sns.heatmap(df.isnull(),cmap='hot')
# Out:
# <Axes: >
